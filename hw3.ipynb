# %% [markdown]
# ## Модель на корпусе текстов советской фантастики

# %% [markdown]
# Для анализа я выбрала подборку советской фантастики про космос - 11 книг. Напишем функцию, которая будет подготавливать тексты для обучения модели:

# %%
from pymorphy2 import MorphAnalyzer
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

morph = MorphAnalyzer()
stops = set(stopwords.words('russian') + ['это', 'весь', 'который', 'мочь', 'свой'])

# %%
def lemmatize(x):
    if type(x) != str:
        return ""
    text = wordpunct_tokenize(x)
    result = []
    for word in text:
        if word.isalpha():
            nf = morph.parse(word)[0].normal_form
            if nf not in stops:
                result.append(nf)
    return " ".join(result)

# %% [markdown]
# Эта функция делит текст из файла на предложения, лемматизирует и токенизирует:

# %%
def tokenize(filename):
    with open ('books/' + filename, 'r', encoding="utf-8") as f:
        text = f.read()
        tokenized = sent_tokenize(text)
        result= ""
        for sent in tokenized:
           result = result + lemmatize(sent) + '\n'
        return result

# %% [markdown]
# Применяем функцию ко всем файлам с книгами:

# %%
import os
list_of_files = os.listdir("books")
print(list_of_files)
with open ('cosmos.txt', 'a', encoding="utf-8") as file:
    for f in list_of_files:
        print(f)
        print(tokenize(f), file=file)
# Out:
# ['strana.txt', 'asgods_1.txt', 'redplanet.txt', 'asgods_2.txt', 'jumpnoth.txt', 'iya.txt', 'mekong.txt', 'kallisto.txt', 'aelita.txt', 'asgods_3.txt', 'almatea.txt']
# strana.txt
# asgods_1.txt
# redplanet.txt
# asgods_2.txt
# jumpnoth.txt
# iya.txt
# mekong.txt
# kallisto.txt
# aelita.txt
# asgods_3.txt
# almatea.txt

# %%
import gensim
import logging
import urllib.request

import warnings
warnings.filterwarnings('ignore')

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
f = 'cosmos.txt'
data = gensim.models.word2vec.LineSentence(f)
# %time model_cosmos = gensim.models.Word2Vec(data, vector_size=300, window=5, min_count=5, epochs=50)
# Out:
# 2021-11-06 18:14:56,816 : INFO : collecting all words and their counts
# 2021-11-06 18:14:56,819 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-11-06 18:14:56,871 : INFO : PROGRESS: at sentence #10000, processed 64516 words, keeping 11249 word types
# 2021-11-06 18:14:56,928 : INFO : PROGRESS: at sentence #20000, processed 125354 words, keeping 15677 word types
# 2021-11-06 18:14:56,979 : INFO : PROGRESS: at sentence #30000, processed 189878 words, keeping 19147 word types
# 2021-11-06 18:14:57,024 : INFO : PROGRESS: at sentence #40000, processed 250679 words, keeping 23332 word types
# 2021-11-06 18:14:57,069 : INFO : PROGRESS: at sentence #50000, processed 310712 words, keeping 26366 word types
# 2021-11-06 18:14:57,110 : INFO : PROGRESS: at sentence #60000, processed 372166 words, keeping 27743 word types
# 2021-11-06 18:14:57,167 : INFO : PROGRESS: at sentence #70000, processed 432345 words, keeping 29270 word types
# 2021-11-06 18:14:57,173 : INFO : collected 29392 word types from a corpus of 438269 raw words and 71180 sentences
# 2021-11-06 18:14:57,174 : INFO : Creating a fresh vocabulary
# 2021-11-06 18:14:57,212 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 11008 unique words (37.452367991290146%% of original 29392, drops 18384)', 'datetime': '2021-11-06T18:14:57.212800', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# 2021-11-06 18:14:57,214 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 405824 word corpus (92.59701233717192%% of original 438269, drops 32445)', 'datetime': '2021-11-06T18:14:57.213967', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# 2021-11-06 18:14:57,281 : INFO : deleting the raw counts dictionary of 29392 items
# 2021-11-06 18:14:57,284 : INFO : sample=0.001 downsamples 14 most-common words
# 2021-11-06 18:14:57,285 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 398549.79952587886 word corpus (98.2%% of prior 405824)', 'datetime': '2021-11-06T18:14:57.285634', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'prepare_vocab'}
# 2021-11-06 18:14:57,419 : INFO : estimated required memory for 11008 words and 300 dimensions: 31923200 bytes
# 2021-11-06 18:14:57,420 : INFO : resetting layer weights
# 2021-11-06 18:14:57,440 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-11-06T18:14:57.440633', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'build_vocab'}
# 2021-11-06 18:14:57,441 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 11008 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2021-11-06T18:14:57.441870', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# 2021-11-06 18:14:58,179 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:14:58,186 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:14:58,188 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:14:58,190 : INFO : EPOCH - 1 : training on 438269 raw words (398609 effective words) took 0.7s, 535786 effective words/s
# 2021-11-06 18:14:58,897 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:14:58,900 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:14:58,919 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:14:58,920 : INFO : EPOCH - 2 : training on 438269 raw words (398522 effective words) took 0.7s, 548638 effective words/s
# 2021-11-06 18:14:59,613 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:14:59,617 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:14:59,629 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:14:59,630 : INFO : EPOCH - 3 : training on 438269 raw words (398536 effective words) took 0.7s, 564719 effective words/s
# 2021-11-06 18:15:00,362 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:00,381 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:00,389 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:00,390 : INFO : EPOCH - 4 : training on 438269 raw words (398582 effective words) took 0.7s, 533679 effective words/s
# 2021-11-06 18:15:01,105 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:01,124 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:01,127 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:01,128 : INFO : EPOCH - 5 : training on 438269 raw words (398546 effective words) took 0.7s, 542815 effective words/s
# 2021-11-06 18:15:01,842 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:01,856 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:01,865 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:01,866 : INFO : EPOCH - 6 : training on 438269 raw words (398580 effective words) took 0.7s, 542543 effective words/s
# 2021-11-06 18:15:02,534 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:02,563 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:02,565 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:02,566 : INFO : EPOCH - 7 : training on 438269 raw words (398525 effective words) took 0.7s, 585919 effective words/s
# 2021-11-06 18:15:03,293 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:03,295 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:03,296 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:03,298 : INFO : EPOCH - 8 : training on 438269 raw words (398431 effective words) took 0.7s, 547468 effective words/s
# 2021-11-06 18:15:03,993 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:04,000 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:04,015 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:04,016 : INFO : EPOCH - 9 : training on 438269 raw words (398471 effective words) took 0.7s, 558608 effective words/s
# 2021-11-06 18:15:04,727 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:04,733 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:04,744 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:04,744 : INFO : EPOCH - 10 : training on 438269 raw words (398559 effective words) took 0.7s, 549653 effective words/s
# 2021-11-06 18:15:05,488 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:05,505 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:05,509 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:05,510 : INFO : EPOCH - 11 : training on 438269 raw words (398591 effective words) took 0.8s, 523193 effective words/s
# 2021-11-06 18:15:06,239 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:06,241 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:06,254 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:06,255 : INFO : EPOCH - 12 : training on 438269 raw words (398495 effective words) took 0.7s, 537792 effective words/s
# 2021-11-06 18:15:07,074 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:07,092 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:07,095 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:07,096 : INFO : EPOCH - 13 : training on 438269 raw words (398550 effective words) took 0.8s, 475883 effective words/s
# 2021-11-06 18:15:07,858 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:07,860 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:07,871 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:07,873 : INFO : EPOCH - 14 : training on 438269 raw words (398530 effective words) took 0.8s, 515807 effective words/s
# 2021-11-06 18:15:08,569 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:08,585 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:08,587 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:08,588 : INFO : EPOCH - 15 : training on 438269 raw words (398575 effective words) took 0.7s, 565244 effective words/s
# 2021-11-06 18:15:09,311 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:09,318 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:09,333 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:09,335 : INFO : EPOCH - 16 : training on 438269 raw words (398512 effective words) took 0.7s, 536142 effective words/s
# 2021-11-06 18:15:10,065 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:10,077 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:10,083 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:10,084 : INFO : EPOCH - 17 : training on 438269 raw words (398507 effective words) took 0.7s, 534314 effective words/s
# 2021-11-06 18:15:10,759 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:10,776 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:10,782 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:10,783 : INFO : EPOCH - 18 : training on 438269 raw words (398522 effective words) took 0.7s, 572779 effective words/s
# 2021-11-06 18:15:11,515 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:11,534 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:11,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:11,541 : INFO : EPOCH - 19 : training on 438269 raw words (398684 effective words) took 0.8s, 528798 effective words/s
# 2021-11-06 18:15:12,248 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:12,258 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:12,259 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:12,260 : INFO : EPOCH - 20 : training on 438269 raw words (398476 effective words) took 0.7s, 557044 effective words/s
# 2021-11-06 18:15:12,970 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:12,978 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:12,988 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:12,990 : INFO : EPOCH - 21 : training on 438269 raw words (398598 effective words) took 0.7s, 548863 effective words/s
# 2021-11-06 18:15:13,749 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:13,757 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:13,761 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:13,762 : INFO : EPOCH - 22 : training on 438269 raw words (398469 effective words) took 0.7s, 563309 effective words/s
# 2021-11-06 18:15:14,489 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:14,493 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:14,509 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:14,511 : INFO : EPOCH - 23 : training on 438269 raw words (398524 effective words) took 0.7s, 540424 effective words/s
# 2021-11-06 18:15:15,229 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:15,233 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:15,251 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:15,252 : INFO : EPOCH - 24 : training on 438269 raw words (398671 effective words) took 0.7s, 578934 effective words/s
# 2021-11-06 18:15:16,009 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:16,013 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:16,021 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:16,022 : INFO : EPOCH - 25 : training on 438269 raw words (398538 effective words) took 0.8s, 524086 effective words/s
# 2021-11-06 18:15:16,742 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:16,754 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:16,764 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:16,766 : INFO : EPOCH - 26 : training on 438269 raw words (398605 effective words) took 0.7s, 538586 effective words/s
# 2021-11-06 18:15:17,474 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:17,477 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:17,484 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:17,485 : INFO : EPOCH - 27 : training on 438269 raw words (398687 effective words) took 0.7s, 557323 effective words/s
# 2021-11-06 18:15:18,245 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:18,254 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:18,268 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:18,270 : INFO : EPOCH - 28 : training on 438269 raw words (398540 effective words) took 0.8s, 520604 effective words/s
# 2021-11-06 18:15:19,055 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:19,064 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:19,068 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:19,068 : INFO : EPOCH - 29 : training on 438269 raw words (398607 effective words) took 0.8s, 502361 effective words/s
# 2021-11-06 18:15:19,760 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:19,765 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:19,767 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:19,768 : INFO : EPOCH - 30 : training on 438269 raw words (398595 effective words) took 0.7s, 573012 effective words/s
# 2021-11-06 18:15:20,466 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:20,470 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:20,487 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:20,488 : INFO : EPOCH - 31 : training on 438269 raw words (398435 effective words) took 0.7s, 556492 effective words/s
# 2021-11-06 18:15:21,157 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:21,169 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:21,180 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:21,181 : INFO : EPOCH - 32 : training on 438269 raw words (398515 effective words) took 0.7s, 577933 effective words/s
# 2021-11-06 18:15:21,847 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:21,864 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:21,870 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:21,871 : INFO : EPOCH - 33 : training on 438269 raw words (398580 effective words) took 0.6s, 638694 effective words/s
# 2021-11-06 18:15:22,602 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:22,625 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:22,627 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:22,628 : INFO : EPOCH - 34 : training on 438269 raw words (398508 effective words) took 0.8s, 528858 effective words/s
# 2021-11-06 18:15:23,280 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:23,297 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:23,298 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:23,299 : INFO : EPOCH - 35 : training on 438269 raw words (398431 effective words) took 0.7s, 600098 effective words/s
# 2021-11-06 18:15:23,967 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:23,977 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:23,990 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:23,991 : INFO : EPOCH - 36 : training on 438269 raw words (398536 effective words) took 0.7s, 585378 effective words/s
# 2021-11-06 18:15:24,727 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:24,733 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:24,737 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:24,739 : INFO : EPOCH - 37 : training on 438269 raw words (398625 effective words) took 0.7s, 535592 effective words/s
# 2021-11-06 18:15:25,418 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:25,423 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:25,426 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:25,427 : INFO : EPOCH - 38 : training on 438269 raw words (398576 effective words) took 0.7s, 581611 effective words/s
# 2021-11-06 18:15:26,113 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:26,115 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:26,122 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:26,123 : INFO : EPOCH - 39 : training on 438269 raw words (398580 effective words) took 0.7s, 576386 effective words/s
# 2021-11-06 18:15:26,839 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:26,850 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:26,852 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:26,853 : INFO : EPOCH - 40 : training on 438269 raw words (398584 effective words) took 0.7s, 548050 effective words/s
# 2021-11-06 18:15:27,569 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:27,589 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:27,591 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:27,592 : INFO : EPOCH - 41 : training on 438269 raw words (398516 effective words) took 0.7s, 542364 effective words/s
# 2021-11-06 18:15:28,265 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:28,292 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:28,294 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:28,295 : INFO : EPOCH - 42 : training on 438269 raw words (398626 effective words) took 0.7s, 569869 effective words/s
# 2021-11-06 18:15:29,030 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:29,040 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:29,052 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:29,054 : INFO : EPOCH - 43 : training on 438269 raw words (398554 effective words) took 0.8s, 528467 effective words/s
# 2021-11-06 18:15:29,731 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:29,736 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:29,754 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:29,755 : INFO : EPOCH - 44 : training on 438269 raw words (398453 effective words) took 0.7s, 575231 effective words/s
# 2021-11-06 18:15:30,541 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:30,543 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:30,556 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:30,557 : INFO : EPOCH - 45 : training on 438269 raw words (398533 effective words) took 0.8s, 498934 effective words/s
# 2021-11-06 18:15:31,252 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:31,261 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:31,267 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:31,268 : INFO : EPOCH - 46 : training on 438269 raw words (398459 effective words) took 0.7s, 562581 effective words/s
# 2021-11-06 18:15:31,937 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:31,942 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:31,952 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:31,952 : INFO : EPOCH - 47 : training on 438269 raw words (398576 effective words) took 0.7s, 585133 effective words/s
# 2021-11-06 18:15:32,655 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:32,669 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:32,677 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:32,678 : INFO : EPOCH - 48 : training on 438269 raw words (398445 effective words) took 0.7s, 551696 effective words/s
# 2021-11-06 18:15:33,409 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:33,417 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:33,419 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:33,420 : INFO : EPOCH - 49 : training on 438269 raw words (398642 effective words) took 0.7s, 540025 effective words/s
# 2021-11-06 18:15:34,140 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-11-06 18:15:34,143 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-11-06 18:15:34,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-11-06 18:15:34,155 : INFO : EPOCH - 50 : training on 438269 raw words (398595 effective words) took 0.7s, 544263 effective words/s
# 2021-11-06 18:15:34,156 : INFO : Word2Vec lifecycle event {'msg': 'training on 21913450 raw words (19927406 effective words) took 36.7s, 542788 effective words/s', 'datetime': '2021-11-06T18:15:34.156339', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'train'}
# 2021-11-06 18:15:34,157 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=11008, vector_size=300, alpha=0.025)', 'datetime': '2021-11-06T18:15:34.157473', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'created'}
# CPU times: user 1min 32s, sys: 3.22 s, total: 1min 35s
# Wall time: 37.3 s

# %%
model_cosmos.init_sims(replace=True)
model_path = "cosmos.bin"
model_cosmos.wv.save_word2vec_format(model_path, binary=True)
# Out:
# 2021-11-06 18:15:42,445 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2021-11-06 18:15:42,461 : INFO : storing 11008x300 projection weights into cosmos.bin

# %% [markdown]
# Посмотрим, сколько в словаре слов:

# %%
print(len(model_cosmos.wv.key_to_index))
# Out:
# 11008

# %% [markdown]
# Слов много, в целом, это хорошо, но может затруднить выполнение семантических задач.

# %% [markdown]
# Попробуем найти ближайшие 10 слов к *космосу*:

# %%
model_cosmos.wv.most_similar("космос", topn=10)
# Out:
# [('простор', 0.5031787753105164),
#  ('пылевой', 0.4858982264995575),
#  ('разверзнуться', 0.48340243101119995),
#  ('пространство', 0.4728526473045349),
#  ('туманность', 0.4683917164802551),
#  ('пустота', 0.4451279044151306),
#  ('расширяться', 0.4319530129432678),
#  ('коллапсар', 0.42654967308044434),
#  ('разлетаться', 0.42319756746292114),
#  ('безмолвие', 0.4156072437763214)]

# %% [markdown]
# Результат достаточно ожидаем: все слова, которые выделила модель, так или иначе связаны с космосом. В выдаче видим преимущественно синонимы - *пространство, простор, пустота*, а также связанные слова - *туманность, коллапсар*. Поскольку корпус изначально собран на научно-фантастических книгах о космических приключениях, такой результат неудивителен: чтобы придать тексту выразительность, авторы использовали синонимы, специальную лексику -- например, *коллапсар*

# %%
model_cosmos.wv.most_similar("аэлит", topn=10) #имя героини - Аэлита, но морфологический анализатор решил иначе
# Out:
# [('аиу', 0.590470552444458),
#  ('лось', 0.49761906266212463),
#  ('гусев', 0.4963341951370239),
#  ('ихошка', 0.49486884474754333),
#  ('прижаться', 0.47197866439819336),
#  ('пепельный', 0.466469407081604),
#  ('капюшон', 0.46589982509613037),
#  ('иха', 0.43821343779563904),
#  ('катя', 0.437086284160614),
#  ('щека', 0.4279519319534302)]

# %% [markdown]
# В выдаче видим фамилии других героев "Аэлиты" - Лося и Гусева, имя Катя, Иха (Ихошка) -- в романе это служанка Аэлиты. Кроме того, модель выделила слово *пепельный*, которое фигурирует в описании внешности героини: у нее были пепельные волосы и пепельные глаза. Интересно, что представлено слово *аиу* -- в романе это одно из слов марсианского языка.

# %% [markdown]
# Посмотрим на синонимы и антонимы:

# %%
model_cosmos.wv.most_similar(positive=["красивый"], negative=["уродливый"], topn=10)
# Out:
# [('уважать', 0.334258496761322),
#  ('супруг', 0.3256406784057617),
#  ('содержательный', 0.31614941358566284),
#  ('спокойный', 0.31056082248687744),
#  ('спасибо', 0.30203527212142944),
#  ('приятный', 0.3009944558143616),
#  ('словечко', 0.29796844720840454),
#  ('деятельный', 0.2957363426685333),
#  ('звучный', 0.2918040454387665),
#  ('дорого', 0.29107123613357544)]

# %% [markdown]
# В выдаче достаточно много прилагательных - содержательный, спокойный, приятный, деятельный, звучный, которые имеют в основном положительную коннотацию, но синонимами или антонимами для красивый/уродливый не являются

# %% [markdown]
# Попробуем найти лишнее слово в ряду. Ожидается, что модель выберет слово *Земля*, поскольку в книгах о космосе другие планеты зачастую противопоставлены Земле:

# %%
model_cosmos.wv.doesnt_match("земля марс венера юпитер".split())
# Out:
# 'земля'

# %% [markdown]
# И действительно, модель работает верно.

# %% [markdown]
# ## Работа с сайтом rusvectores

# %%
urllib.request.urlretrieve("http://rusvectores.org/static/models/rusvectores2/ruscorpora_mystem_cbow_300_2_2015.bin.gz", "ruscorpora_mystem_cbow_300_2_2015.bin.gz")
# Out:
# ('ruscorpora_mystem_cbow_300_2_2015.bin.gz',
#  <http.client.HTTPMessage at 0x7f659646d550>)

# %%
m = 'ruscorpora_mystem_cbow_300_2_2015.bin.gz'

if m.endswith('.vec.gz'):
    model = gensim.models.KeyedVectors.load_word2vec_format(m, binary=False)
elif m.endswith('.bin.gz'):
    model = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
else:
    model = gensim.models.KeyedVectors.load(m)
# Out:
# 2021-11-06 18:19:06,147 : INFO : loading projection weights from ruscorpora_mystem_cbow_300_2_2015.bin.gz
# 2021-11-06 18:19:11,025 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (281776, 300) matrix of type float32 from ruscorpora_mystem_cbow_300_2_2015.bin.gz', 'binary': True, 'encoding': 'utf8', 'datetime': '2021-11-06T18:19:11.025604', 'gensim': '4.1.2', 'python': '3.8.10 (default, Jun  2 2021, 10:49:15) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.29', 'event': 'load_word2vec_format'}

# %% [markdown]
# Попробуем составить семантическую пропорцию женщина - девочка + мужчина = мальчик. Посмотрим, каким будет результат модели:

# %%
print(model.most_similar(positive=['женщина_S', 'мужчина_S'], negative=['девочка_S'])[0][0])
# Out:
# человек_S

# %% [markdown]
# Вместо *мальчика* получили *человека*, то есть исходная пропорция в понимании модели выглядит так: *женщина - девочка = мужчина - человек*

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Попробуем сделать визуализацию для абстрактных понятий:

# %%
words = ['смерть_S', 'страдание_S', 'любовь_S','одиночество_S', 'преданность_S', 'ненависть_S', 'дружба_S', 'верность_S', 'печаль_S', 'обожание_S', 'радость_S']
X = model[words]

# %%
pca = PCA(n_components=2)
coords = pca.fit_transform(X)
plt.scatter(coords[:, 0], coords[:, 1], color='red')
plt.title('Words')

for i, word in enumerate(words):
    plt.annotate(word, xy=(coords[i, 0], coords[i, 1]))
plt.show()

# %% [markdown]
# В целом, результат противоречивый: с одной стороны, в визуализации близки слова верность, дружба, преданность,  а также страдание и одиночество, что соответсвтвует действительности. С другой -- ненависть оказалась ближе к любви, чем обожание, печаль и радость рядом.

# %% [markdown]
# Возьмем первое предложение из романа "Мастер и Маргарита", лемматизируем и уберем служебные слова. Чтобы формат записи предложения совпал с форматом, который принимает наша модель, используем mystem, добавим частеречные тэги:

# %%
from pymystem3 import Mystem
m = Mystem()

# %%
sent = "Однажды весной, в час небывало жаркого заката, в Москве, на Патриарших прудах, появились два гражданина."
sent_lemmatized = lemmatize(sent).split()
sent_parsed = []
for word in sent_lemmatized:
    ana = m.analyze(word)
    gr = ana[0]['analysis'][0]['gr']
    pos = gr.split('=')[0].split(',')[0]
    sent_parsed.append(ana[0]['text'] + '_' + pos)

# %% [markdown]
# Применим модель к каждому слову:

# %%
res = []
for word in sent_parsed:
    smword = model.most_similar(word, topn=1)[0][0]
    res.append(smword)
res
# Out:
# ['вчера_ADV',
#  'осень_S',
#  'полчаса_S',
#  'невиданный_A',
#  'знойный_A',
#  'закатный_A',
#  'петербург_S',
#  'патриерший_S',
#  'озеро_S',
#  'эллис_S',
#  'гражданство_S']

# %% [markdown]
# Получается такое предложение: *Вчера осенью, в полчаса невиданного знойного закатного, в Петербурге, на Патриершем озере, эллис (?) два гражданства.*

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# Возьмем статьи из Википедии из категории "мультфильмы о ведьмах" (https://ru.wikipedia.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%9C%D1%83%D0%BB%D1%8C%D1%82%D1%84%D0%B8%D0%BB%D1%8C%D0%BC%D1%8B_%D0%BE_%D0%B2%D0%B5%D0%B4%D1%8C%D0%BC%D0%B0%D1%85)

# %%
import wikipedia
from tqdm.auto import tqdm
wikipedia.set_lang('ru')
article_names = ["Белоснежка и семь гномов (мультфильм)", "Ведьмина служба доставки", "Верхом на помеле (мультфильм)", "Дети против волшебников (мультфильм)", "Добрыня Никитич и Змей Горыныч", "Дракон и тапочка королевы", "Карлик Нос (мультфильм)", "Маленькая колдунья (мультфильм)", "Мальчик из Неаполя", "Меч в камне (мультфильм)", "Мэри и ведьмин цветок", "Ореховый прутик", "Паранорман, или Как приручить зомби", "Рапунцель: Запутанная история", "Русалочка (мультфильм, 1989)", "Русалочка 2: Возвращение в море", "Скуби-Ду и призрак ведьмы", "Скуби-Ду и Школа вампиров", "Скуби-Ду, где ты!", "Спящая красавица (мультфильм)", "Три богатыря на дальних берегах", "Унесённые призраками", "Храбрая сердцем", "Bewitched Bunny", "Brynhildr in the Darkness", "Rosario + Vampire"]

articles = []
for page_name in tqdm(article_names):
    try:
        text = wikipedia.page(page_name).content
        articles.append((page_name, text))
    except:
        print("Error", page_name)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]

# %% [markdown]
# Подготовим TF-IDF, введем необходимые параметры:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer="word",
    stop_words=stops,
    ngram_range = (1, 3), #число слов
    min_df = 3 #минимальное число вхождений
)

# %% [markdown]
# Подготовим тексты статей, лемматизируем, избавимся от знаков препинания:

# %%
articles_preprocessed = []
for a_text in articles:
    a_lemmatized = lemmatize(a_text[1])
    articles_preprocessed.append(a_lemmatized)

# %% [markdown]
# Пропускаем через TF-IDF:

# %%
articles_tfidf = tfidf.fit_transform(articles_preprocessed)
print(f"Матрица на {articles_tfidf.shape[0]} документов и {articles_tfidf.shape[1]} термов")
# Out:
# Матрица на 26 документов и 2056 термов

# %% [markdown]
# Выделим для каждой статьи ключевые слова:

# %%
import numpy as np
def get_top_tf_idf_words(tfidf_vector, feature_names, top_n):
    sorted_nzs = np.argsort(tfidf_vector.data)[:-(top_n+1):-1]
    return feature_names[tfidf_vector.indices[sorted_nzs]]

# %%
feature_names = np.array(tfidf.get_feature_names())

for i, article in enumerate(articles):
    article_vector = articles_tfidf[i, :]
    words = get_top_tf_idf_words(article_vector, feature_names, 10)
    print(article[0])
    print(words)
# Out:
# Белоснежка и семь гномов (мультфильм)
# ['белоснежок' 'гном' 'дисней' 'королева' 'семь гном' 'уолт' 'год' 'семь'
#  'фильм' 'мультфильм']
# Ведьмина служба доставки
# ['фильм' 'японский' 'служба' 'книга' 'яп' 'аниме' 'её' 'кот' 'год' 'город']
# Верхом на помеле (мультфильм)
# ['фильм' 'кот' 'птица' 'дракон' 'книга' 'ведьма' 'пёс' 'верхом'
#  'фильм сайт' 'информация']
# Дети против волшебников (мультфильм)
# ['иван' 'фильм' 'мультфильм' 'разработчик' 'российский' 'волшебник'
#  'картина' 'фонд' 'ребёнок' 'поддержка']
# Добрыня Никитич и Змей Горыныч
# ['змея' 'хан' 'игра' 'однако' 'выдать' 'приказ' 'издаваться' 'год'
#  'мультфильм' 'предлагать']
# Дракон и тапочка королевы
# ['королева' 'король' 'артур' 'дракон' 'король артур' 'пирог' 'рыцарь'
#  'мерлина' 'зелье' 'время']
# Карлик Нос (мультфильм)
# ['фестиваль' 'колдунья' 'детский' 'оригинал' 'международный' 'год' 'фильм'
#  'семь год' 'приз' 'мультфильм']
# Маленькая колдунья (мультфильм)
# ['мультфильм' 'книга' 'геннадий' 'ведьма' 'старушка' 'колдунья' 'главный'
#  'маленький' 'юрий' 'сказать']
# Мальчик из Неаполя
# ['сборник' 'сказка' 'иван' 'мультфильм' 'мальчик' 'глобус'
#  'сборник мультфильм' 'режиссёр' 'волшебный' 'гора']
# Меч в камне (мультфильм)
# ['артур' 'меч' 'мерлина' 'disney' 'the' 'александр' 'stone' 'король' 'год'
#  'in the']
# Мэри и ведьмин цветок
# ['мэри' 'цветок' 'мадам' 'доктор' 'метла' 'ведьмин' 'заклинание' 'её'
#  'ведьма' 'магический']
# Ореховый прутик
# ['сборник' 'колдунья' 'злой колдунья' 'мультфильм' 'брат' 'пещера'
#  'сборник мультфильм' 'ворон' 'фестиваль' 'помочь']
# Паранорман, или Как приручить зомби
# ['норман' 'призрак' 'мистер' 'бабушка' 'анна' 'мультфильм' 'алексей'
#  'август' 'англ' 'отзыв']
# Рапунцель: Запутанная история
# ['волос' 'фильм' 'мультфильм' 'принцесса' 'disney' 'история' 'девушка'
#  'брат' 'дисней' 'сделать']
# Русалочка (мультфильм, 1989)
# ['ариэль' 'урсула' 'эрик' 'русалочка' 'мюзикл' 'корабль' 'год' 'принц'
#  'её' 'себастьян']
# Русалочка 2: Возвращение в море
# ['ариэль' 'царь' 'море' 'эрик' 'себастьян' 'дедушка' 'дочь' 'русалочка'
#  'урсула' 'год']
# Скуби-Ду и призрак ведьмы
# ['скубить ду' 'ду' 'скубить' 'ведьма' 'призрак' 'дух' 'книга' 'городок'
#  'местный' 'заклинание']
# Скуби-Ду и Школа вампиров
# ['скубить' 'дочь' 'школа' 'ду' 'шэгга' 'scooby doo' 'scooby' 'doo'
#  'ученица' 'and the']
# Скуби-Ду, где ты!
# ['скубить' 'ду' 'скубить ду' 'scooby' 'мультсериал' 'scooby doo' 'doo'
#  'шэгга' 'год' 'мультфильм']
# Спящая красавица (мультфильм)
# ['спать' 'красавица' 'дисней' 'принцесса' 'принц' 'уолт' 'год' 'сон'
#  'добрый' 'уолт дисней']
# Три богатыря на дальних берегах
# ['бочка' 'берег' 'мультфильм' 'следующий день' 'мельница' 'франшиза'
#  'корабль' 'вызывать' 'следующий' 'остров']
# Унесённые призраками
# ['фильм' 'призрак' 'яп' 'год' 'японский' 'and' 'of' 'япония' 'сэйя' 'мир']
# Храбрая сердцем
# ['pixar' 'дочь' 'медведь' 'фильм' 'королева' 'брат' 'ведьма' 'мультфильм'
#  'замок' 'отец']
# Bewitched Bunny
# ['ведьма' 'мультфильм' 'collection' 'сказка брат гримм' 'сказка брат'
#  'брат гримм' 'гримм' 'англ' 'русый' 'сказка']
# Brynhildr in the Darkness
# ['яп' 'магия' 'волшебница' 'сэйя' 'её' 'тело' 'сбежать' 'использовать'
#  'человек' 'время']
# Rosario + Vampire
# ['манга' 'аниме' 'сезон' 'tv' 'год' 'яп' 'серия' 'второй сезон' 'второй'
#  'вампир']
# /home/zadushevno/hws/hw3/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# В целом для многих статей ключевые слова отражают содержание, но не для всех. Обычно в ключевые слова попадают имена героев, важные предметы. Часто вместо содержания ключевые статьи отражают год и страну производства.

# %% [markdown]
# Когда я пыталась сделать визуализацию с помощью PCA, программа выдавала ошибку (*PCA does not support sparse input. See TruncatedSVD for a possible alternative*), которую я так и не поняла, как исправить, и предлагала использовать TruncatedSVD, что я в итоге и сделала:

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=2)
coords = svd.fit_transform(articles_tfidf)
plt.figure(figsize=(20, 10))
plt.scatter(coords[:, 0], coords[:, 1], color='green')
plt.title('Статьи') 

for i, article in enumerate(articles):
    plt.annotate(article[0], xy=(coords[i, 0], coords[i, 1]))
plt.show()

# %% [markdown]
# Похожие тексты действительно находятся рядом: например, все статьи про Скуби-Ду на графике в одной области, две "Русалочки" тоже недалеко друг от друга. Аниме "Унесенные призраками" и "Ведьмина служба доставки", созданные одной студией, оказались рядом.

# %% [markdown]
# ## Сайт RusVectores

# %% [markdown]
# ### 1. Раздел похожие слова
#
# Посмотрим на семантические ассоциаты для слова *мечта*:
#
# **НКРЯ**
# мечтание NOUN 0.75
#
# греза NOUN 0.70
#
# грез NOUN 0.70
#
# мечтать VERB 0.65
#
# мечта PROPN 0.57
#
# несбыточный ADJ 0.57
#
# утопия NOUN 0.56
#
# идеал NOUN 0.55
#
# надежда NOUN 0.55
#
# фантазия NOUN 0.53
#
#
# **НКРЯ и Wikipedia**
#
# мечтание NOUN 0.70
#
# надежда NOUN 0.63
#
# мечтать VERB 0.59
#
# греза NOUN 0.59
#
# несбыточный ADJ 0.59
#
# желание NOUN 0.58
#
# грез NOUN 0.58
#
# чаяние NOUN 0.56
#
# мечта PROPN 0.55
#
# фантазия NOUN 0.55
#
#
# **Новостной корпус**
#
# ярзабковска ADV 0.41
#
# сбываться VERB 0.41
#
#
# **GeoWAC fastText**
#
# мечтание 0.74
#
# несбыточный 0.69
#
# мечтать 0.66
#
# сбываться 0.63
#
# заветный 0.63
#
# грез 0.61
#
# греза 0.60
#
# мечтатель 0.59
#
# воплощать 0.59
#
# желанье 0.58
#
#
# **Тайга**
#
# мечта VERB 0.76
#
# мечтание NOUN 0.75
#
# мечта PROPN 0.73
#
# несбыточный ADJ 0.68
#
# греза NOUN 0.66
#
# грез NOUN 0.62
#
# несбыться VERB 0.62
#
# мечтать VERB 0.57
#
# сбываться VERB 0.54
#
# грезить VERB 0.53

# %% [markdown]
# Слово *мечта* распространенное, четких выводов о содержании корпусов сделать нельзя, так как соседи одни и те же -- мечтание, греза, желание, сбываться. В НКРЯ и Википедия, кажется, больше разнообразных текстов, чем в Тайге или GeoWac, так как мы видим больше слов с разными корнями, а не только производные от мечта и греза.
#
# Новостной корпус наиболее отличается от остальных из-за специфики содержания (в нем только новостные тексты, а абстрактные понятия мы скорее ожидаем встретить в художественных)

# %% [markdown]
# Посмотрим на ассоциаты для термина *аффикс*:
#
# **НКРЯ**
#
# лексический ADJ 0.61
#
# фонема NOUN 0.59
#
# суффикс NOUN 0.58
#
# лексема NOUN 0.57
#
# синтаксический ADJ 0.57
#
# существительное ADJ 0.56
#
# глагольный ADJ 0.55
#
# прилагательное NOUN 0.55
#
# грамматический ADJ 0.54
#
# прилагательное ADJ 0.53
#
# **НКРЯ и Wikipedia**
#
# суффикс NOUN 0.77
#
# морфема NOUN 0.73
#
# местоимение NOUN 0.72
#
# глагольный ADJ 0.72
#
# глагол NOUN 0.72
#
# падежный ADJ 0.71
#
# прилагательное ADJ 0.70
#
# существительное ADJ 0.70
#
# флексия NOUN 0.67
#
# инфинитив NOUN 0.67
#
# **Новостной корпус** -- Модели неизвестно слово "аффикс_NOUN"
#
# **GeoWAC fastText**
#
# суффикс 0.78
#
# существительное 0.64
#
# глагол 0.63
#
# прилагательное 0.60
#
# местоимение 0.59
#
# наречие 0.56
#
# согласная 0.54
#
# гласная 0.52
#
# падеж 0.51
#
# фразеологизм 0.51
#
# **Тайга**
#
# суффикс NOUN 0.66
#
# местоимение NOUN 0.59
#
# фонема NOUN 0.56
#
# прилагательное ADJ 0.53
#
# глагольный ADJ 0.52

# %% [markdown]
# Интересно, что в НКРЯ ассоциаты прилагательные лексический, грамматический, синтаксический, то есть виды аффиксов, в других корпусах -- преимущественно существительные, другие термины, связанные с лингвистикой. В Новостном корпусе и вовсе нет слова аффикс, так как тексты этого корпуса не научные. В Тайге и GeoWAC, по сравнению с НКРЯ и Википедией, более примитивные соседи, что о говорит о том, что и в этих корпусах доля научных текстов значительно ниже, чем в НКРЯ.

# %% [markdown]
# Посмотрим на ассоциаты для слова *полотенце*:
#
# **НКРЯ**
#
# простыня NOUN 0.69
#
# салфетка NOUN 0.65
#
# тряпка NOUN 0.62
#
# платок NOUN 0.62
#
# рушник NOUN 0.61
#
# тряпочка NOUN 0.61
#
# мочалка NOUN 0.60
#
# одеяло NOUN 0.57
#
# рукомойник NOUN 0.57
#
# тряпица NOUN 0.57
#
# **НКРЯ и Wikipedia**
#
# простыня NOUN 0.74
#
# платок NOUN 0.70
#
# салфетка NOUN 0.69
#
# тряпка NOUN 0.65
#
# одеяло NOUN 0.65
#
# скатерть NOUN 0.64
#
# тряпица NOUN 0.63
#
# белье NOUN 0.63
#
# передник NOUN 0.62
#
# халат NOUN 0.62
#
# **Новостной корпус**
#
# салфетка NOUN 0.60
#
# брюки NOUN 0.56
#
# **GeoWAC fastText**
#
# салфетка 0.71
#
# простыня 0.68
#
# тапочка 0.66
#
# мочалка 0.65
#
# одеяло 0.65
#
# халат 0.63
#
# махровый 0.62
#
# скатерть 0.61
#
# белье 0.61
#
# пеленок 0.61
#
# **Тайга**
#
# простыня NOUN 0.72
#
# салфетка NOUN 0.70
#
# вытереться VERB 0.68
#
# мочалка NOUN 0.67
#
# платок NOUN 0.67
#
# тряпка NOUN 0.63
#
# тряпица NOUN 0.63
#
# простыня ADJ 0.63
#
# наволочка NOUN 0.63
#
# плед NOUN 0.63

# %% [markdown]
# Для этого слова результаты для всех корпусов (кроме Новостного) наиболее похожие и однозначные: первые две позиции занимают слова простыня и салфетка, а вот последующее распределение зависит от содержания корпуса. В НКРЯ есть старые тексты, поэтому и среди ассоциатов видим необычные варианты -- рушник, рукомойник, тряпица. В НКРЯ и Википедии, под влиянием последней, платок располагается на втором месте, выше салфетки и тряпки, а также присутствуют другие элементы быта - скатерть, халат, передник.
#
# Интересно, что глагол оказался только в выдачи Тайги.

# %% [markdown]
# ### Раздел визуализация
#
# Возьмем слова зависть, стыд, удивление, отвращение, восхищение, грусть, радость, злость, страх, разочарование. Картинки с визуализацией размещены в папке "Визуализация".

# %% [markdown]
# ### Раздел калькулятор
# Посмотрим, какой результат покажут модели для пропорции лингвист - язык, филолог - ?
#
# **НКРЯ**
#
# латынь NOUN 0.56
#
# словесность NOUN 0.51
#
# грамматика NOUN 0.48
#
# хрестоматия NOUN 0.47
#
# литература NOUN 0.46
#
# **НКРЯ и Wikipedia**
#
# латынь NOUN 0.54
#
# языке NOUN 0.53
#
# язык PROPN 0.50
#
# церковнославянский ADJ 0.48
#
# языке VERB 0.47
#
# **Новостной корпус**
#
# русский ADJ 0.45
#
# **GeoWAC fastText**
#
# английский 0.66
#
# филология 0.64
#
# языке 0.62
#
# преподавание 0.58
#
# русский 0.57
#
# **Тайга**
#
# язык PROPN 0.53
#
# грамматика NOUN 0.53
#
# латынь NOUN 0.52
#
# диалект NOUN 0.52
#
# идиш NOUN 0.49

# %% [markdown]
# Выдача модели на основе НКРЯ наиболее разнообразна, так как в этом корпусе, вероятно, больше текстов, где упоминаются слова лингвист и филолог, чего не скажешь о других корпусах. В целом модели скорее не видят различий между этими словами.

# %% [markdown]
# ### Раздел 2D текст

# %% [markdown]
# Возьмем первое предложение из романа "Мастер и Маргарита", с которым уже работали выше, и пословицу "Без труда не вытащить и рыбку из пруда".

# %% [markdown]
# Получаем вот такие варианты для предложения:
#
# *Вчера	осенью	в	день	довольно	сильного	солнца	в	Одессе	на	улицах	улицах	появляются	три	людей*
#
# *Как-то	ночью	в	месяц	столь	солнца	обеда	в	Петербурге	на	официальных	домах	возникли	четыре	военнослужащих*
#
# *Вечером	зимой	в	вечер	чрезвычайно	раннего	лета	в	Киеве	на	московских	озере	имеются	Два	евреев*
#
# *Наконец	летом	в	миг	бесконечно	большого	неба	в	Санкт-Петербурге	на	черных	горах	начались	двое	гостей*
#
# *Утром	вечером	в	полчаса	праздника	обычного	праздника	в	Париже	на	открытых	полях	появилась	Четыре	крестьян*

# %% [markdown]
# Замены скорее неадекватные, полностью искажающие смысл предложения. Меняется и время года, и место действия, и число людей, а также то, что это за люди (вместо граждан -- евреи и крестьяне)

# %% [markdown]
# Для пословицы:
#
# *Без	трудом	не	купить	и	девушку	из	озера*
#
# *Без	ума	не	взять	и	женщину	из	сада*
#
# *Без	счастья	не	вывести	и	бутылку	из	залива*
#
# *Без	усилий	не	найти	и	лошадь	из	водохранилища*
#
# *Без	голода	не	поднять	и	еду	из	моста*

# %% [markdown]
# Замены еще более неадекватные, смысл пословицы совсем теряется, а предложения получаются абсурдными.

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# 2. Параметр token_pattern принимает регулярное выражение, которому должно соотвествовать каждое слово в словаре. Чтобы цифры не попадали в словарь, можно задать обучение модели так:

# %%
regex = '[а-яА-я]+' #если нам нужны не только русские слова: '[а-яА-яa-zA-Z]+'
tfidf_1 = TfidfVectorizer(
    analyzer="word",
    stop_words=stops,
    ngram_range = (1, 3), #число слов
    min_df = 3, #минимальное число вхождений
    token_pattern=regex
)

# %% [markdown]
# С помощью функции cosine_similarity и pandas создадим матрицу схожести текстов на основе их векторов:

# %%
from sklearn.metrics.pairwise import cosine_similarity
sm = cosine_similarity(articles_tfidf)

# %%
import pandas as pd
df = pd.DataFrame(sm, columns=article_names, index=article_names)
df
# Out:
#                                        Белоснежка и семь гномов (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                               1.000000
# Ведьмина служба доставки                                            0.292333
# Верхом на помеле (мультфильм)                                       0.143808
# Дети против волшебников (мультфильм)                                0.220115
# Добрыня Никитич и Змей Горыныч                                      0.121431
# Дракон и тапочка королевы                                           0.179821
# Карлик Нос (мультфильм)                                             0.208547
# Маленькая колдунья (мультфильм)                                     0.150106
# Мальчик из Неаполя                                                  0.135854
# Меч в камне (мультфильм)                                            0.170720
# Мэри и ведьмин цветок                                               0.064704
# Ореховый прутик                                                     0.125689
# Паранорман, или Как приручить зомби                                 0.059368
# Рапунцель: Запутанная история                                       0.376930
# Русалочка (мультфильм, 1989)                                        0.232022
# Русалочка 2: Возвращение в море                                     0.160597
# Скуби-Ду и призрак ведьмы                                           0.063206
# Скуби-Ду и Школа вампиров                                           0.041694
# Скуби-Ду, где ты!                                                   0.086911
# Спящая красавица (мультфильм)                                       0.439205
# Три богатыря на дальних берегах                                     0.123528
# Унесённые призраками                                                0.261208
# Храбрая сердцем                                                     0.297624
# Bewitched Bunny                                                     0.148002
# Brynhildr in the Darkness                                           0.102661
# Rosario + Vampire                                                   0.158875
#
#                                        Ведьмина служба доставки  \
# Белоснежка и семь гномов (мультфильм)                  0.292333
# Ведьмина служба доставки                               1.000000
# Верхом на помеле (мультфильм)                          0.321257
# Дети против волшебников (мультфильм)                   0.365360
# Добрыня Никитич и Змей Горыныч                         0.162681
# Дракон и тапочка королевы                              0.065369
# Карлик Нос (мультфильм)                                0.277731
# Маленькая колдунья (мультфильм)                        0.226747
# Мальчик из Неаполя                                     0.156136
# Меч в камне (мультфильм)                               0.146678
# Мэри и ведьмин цветок                                  0.156344
# Ореховый прутик                                        0.147372
# Паранорман, или Как приручить зомби                    0.095394
# Рапунцель: Запутанная история                          0.388703
# Русалочка (мультфильм, 1989)                           0.245649
# Русалочка 2: Возвращение в море                        0.169138
# Скуби-Ду и призрак ведьмы                              0.129954
# Скуби-Ду и Школа вампиров                              0.056315
# Скуби-Ду, где ты!                                      0.104275
# Спящая красавица (мультфильм)                          0.316139
# Три богатыря на дальних берегах                        0.173044
# Унесённые призраками                                   0.609075
# Храбрая сердцем                                        0.290407
# Bewitched Bunny                                        0.091131
# Brynhildr in the Darkness                              0.327424
# Rosario + Vampire                                      0.322007
#
#                                        Верхом на помеле (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                       0.143808
# Ведьмина служба доставки                                    0.321257
# Верхом на помеле (мультфильм)                               1.000000
# Дети против волшебников (мультфильм)                        0.180278
# Добрыня Никитич и Змей Горыныч                              0.106093
# Дракон и тапочка королевы                                   0.141301
# Карлик Нос (мультфильм)                                     0.173076
# Маленькая колдунья (мультфильм)                             0.179906
# Мальчик из Неаполя                                          0.096347
# Меч в камне (мультфильм)                                    0.097023
# Мэри и ведьмин цветок                                       0.074601
# Ореховый прутик                                             0.088478
# Паранорман, или Как приручить зомби                         0.063755
# Рапунцель: Запутанная история                               0.190432
# Русалочка (мультфильм, 1989)                                0.112476
# Русалочка 2: Возвращение в море                             0.085262
# Скуби-Ду и призрак ведьмы                                   0.164969
# Скуби-Ду и Школа вампиров                                   0.079537
# Скуби-Ду, где ты!                                           0.071800
# Спящая красавица (мультфильм)                               0.130721
# Три богатыря на дальних берегах                             0.102420
# Унесённые призраками                                        0.287338
# Храбрая сердцем                                             0.210435
# Bewitched Bunny                                             0.148059
# Brynhildr in the Darkness                                   0.063716
# Rosario + Vampire                                           0.088300
#
#                                        Дети против волшебников (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                              0.220115
# Ведьмина служба доставки                                           0.365360
# Верхом на помеле (мультфильм)                                      0.180278
# Дети против волшебников (мультфильм)                               1.000000
# Добрыня Никитич и Змей Горыныч                                     0.181064
# Дракон и тапочка королевы                                          0.080540
# Карлик Нос (мультфильм)                                            0.266089
# Маленькая колдунья (мультфильм)                                    0.242413
# Мальчик из Неаполя                                                 0.261768
# Меч в камне (мультфильм)                                           0.136337
# Мэри и ведьмин цветок                                              0.052282
# Ореховый прутик                                                    0.179724
# Паранорман, или Как приручить зомби                                0.089971
# Рапунцель: Запутанная история                                      0.355444
# Русалочка (мультфильм, 1989)                                       0.183156
# Русалочка 2: Возвращение в море                                    0.121860
# Скуби-Ду и призрак ведьмы                                          0.073403
# Скуби-Ду и Школа вампиров                                          0.037811
# Скуби-Ду, где ты!                                                  0.101538
# Спящая красавица (мультфильм)                                      0.241817
# Три богатыря на дальних берегах                                    0.236183
# Унесённые призраками                                               0.316917
# Храбрая сердцем                                                    0.252330
# Bewitched Bunny                                                    0.119066
# Brynhildr in the Darkness                                          0.117681
# Rosario + Vampire                                                  0.173346
#
#                                        Добрыня Никитич и Змей Горыныч  \
# Белоснежка и семь гномов (мультфильм)                        0.121431
# Ведьмина служба доставки                                     0.162681
# Верхом на помеле (мультфильм)                                0.106093
# Дети против волшебников (мультфильм)                         0.181064
# Добрыня Никитич и Змей Горыныч                               1.000000
# Дракон и тапочка королевы                                    0.075146
# Карлик Нос (мультфильм)                                      0.240668
# Маленькая колдунья (мультфильм)                              0.089480
# Мальчик из Неаполя                                           0.124330
# Меч в камне (мультфильм)                                     0.081335
# Мэри и ведьмин цветок                                        0.048570
# Ореховый прутик                                              0.147650
# Паранорман, или Как приручить зомби                          0.043288
# Рапунцель: Запутанная история                                0.186806
# Русалочка (мультфильм, 1989)                                 0.127866
# Русалочка 2: Возвращение в море                              0.096106
# Скуби-Ду и призрак ведьмы                                    0.061117
# Скуби-Ду и Школа вампиров                                    0.031406
# Скуби-Ду, где ты!                                            0.061845
# Спящая красавица (мультфильм)                                0.129189
# Три богатыря на дальних берегах                              0.221127
# Унесённые призраками                                         0.169802
# Храбрая сердцем                                              0.154587
# Bewitched Bunny                                              0.072556
# Brynhildr in the Darkness                                    0.077857
# Rosario + Vampire                                            0.121395
#
#                                        Дракон и тапочка королевы  \
# Белоснежка и семь гномов (мультфильм)                   0.179821
# Ведьмина служба доставки                                0.065369
# Верхом на помеле (мультфильм)                           0.141301
# Дети против волшебников (мультфильм)                    0.080540
# Добрыня Никитич и Змей Горыныч                          0.075146
# Дракон и тапочка королевы                               1.000000
# Карлик Нос (мультфильм)                                 0.069738
# Маленькая колдунья (мультфильм)                         0.046369
# Мальчик из Неаполя                                      0.047141
# Меч в камне (мультфильм)                                0.311271
# Мэри и ведьмин цветок                                   0.016778
# Ореховый прутик                                         0.042997
# Паранорман, или Как приручить зомби                     0.029266
# Рапунцель: Запутанная история                           0.122865
# Русалочка (мультфильм, 1989)                            0.057391
# Русалочка 2: Возвращение в море                         0.067403
# Скуби-Ду и призрак ведьмы                               0.077147
# Скуби-Ду и Школа вампиров                               0.090757
# Скуби-Ду, где ты!                                       0.023731
# Спящая красавица (мультфильм)                           0.137870
# Три богатыря на дальних берегах                         0.074963
# Унесённые призраками                                    0.092582
# Храбрая сердцем                                         0.258509
# Bewitched Bunny                                         0.175611
# Brynhildr in the Darkness                               0.034761
# Rosario + Vampire                                       0.047898
#
#                                        Карлик Нос (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                 0.208547
# Ведьмина служба доставки                              0.277731
# Верхом на помеле (мультфильм)                         0.173076
# Дети против волшебников (мультфильм)                  0.266089
# Добрыня Никитич и Змей Горыныч                        0.240668
# Дракон и тапочка королевы                             0.069738
# Карлик Нос (мультфильм)                               1.000000
# Маленькая колдунья (мультфильм)                       0.230184
# Мальчик из Неаполя                                    0.197865
# Меч в камне (мультфильм)                              0.108028
# Мэри и ведьмин цветок                                 0.053420
# Ореховый прутик                                       0.320655
# Паранорман, или Как приручить зомби                   0.076826
# Рапунцель: Запутанная история                         0.281771
# Русалочка (мультфильм, 1989)                          0.143112
# Русалочка 2: Возвращение в море                       0.138000
# Скуби-Ду и призрак ведьмы                             0.082988
# Скуби-Ду и Школа вампиров                             0.035106
# Скуби-Ду, где ты!                                     0.086095
# Спящая красавица (мультфильм)                         0.225371
# Три богатыря на дальних берегах                       0.134984
# Унесённые призраками                                  0.281434
# Храбрая сердцем                                       0.232394
# Bewitched Bunny                                       0.107315
# Brynhildr in the Darkness                             0.084507
# Rosario + Vampire                                     0.160573
#
#                                        Маленькая колдунья (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                         0.150106
# Ведьмина служба доставки                                      0.226747
# Верхом на помеле (мультфильм)                                 0.179906
# Дети против волшебников (мультфильм)                          0.242413
# Добрыня Никитич и Змей Горыныч                                0.089480
# Дракон и тапочка королевы                                     0.046369
# Карлик Нос (мультфильм)                                       0.230184
# Маленькая колдунья (мультфильм)                               1.000000
# Мальчик из Неаполя                                            0.313767
# Меч в камне (мультфильм)                                      0.115937
# Мэри и ведьмин цветок                                         0.068124
# Ореховый прутик                                               0.262891
# Паранорман, или Как приручить зомби                           0.070040
# Рапунцель: Запутанная история                                 0.240517
# Русалочка (мультфильм, 1989)                                  0.146324
# Русалочка 2: Возвращение в море                               0.116285
# Скуби-Ду и призрак ведьмы                                     0.162724
# Скуби-Ду и Школа вампиров                                     0.027210
# Скуби-Ду, где ты!                                             0.075447
# Спящая красавица (мультфильм)                                 0.182808
# Три богатыря на дальних берегах                               0.151805
# Унесённые призраками                                          0.139749
# Храбрая сердцем                                               0.239525
# Bewitched Bunny                                               0.204417
# Brynhildr in the Darkness                                     0.067282
# Rosario + Vampire                                             0.069002
#
#                                        Мальчик из Неаполя  \
# Белоснежка и семь гномов (мультфильм)            0.135854
# Ведьмина служба доставки                         0.156136
# Верхом на помеле (мультфильм)                    0.096347
# Дети против волшебников (мультфильм)             0.261768
# Добрыня Никитич и Змей Горыныч                   0.124330
# Дракон и тапочка королевы                        0.047141
# Карлик Нос (мультфильм)                          0.197865
# Маленькая колдунья (мультфильм)                  0.313767
# Мальчик из Неаполя                               1.000000
# Меч в камне (мультфильм)                         0.127251
# Мэри и ведьмин цветок                            0.030171
# Ореховый прутик                                  0.461669
# Паранорман, или Как приручить зомби              0.065337
# Рапунцель: Запутанная история                    0.204130
# Русалочка (мультфильм, 1989)                     0.130378
# Русалочка 2: Возвращение в море                  0.096654
# Скуби-Ду и призрак ведьмы                        0.049806
# Скуби-Ду и Школа вампиров                        0.020063
# Скуби-Ду, где ты!                                0.062069
# Спящая красавица (мультфильм)                    0.144441
# Три богатыря на дальних берегах                  0.104591
# Унесённые призраками                             0.124475
# Храбрая сердцем                                  0.185838
# Bewitched Bunny                                  0.159527
# Brynhildr in the Darkness                        0.036661
# Rosario + Vampire                                0.082000
#
#                                        Меч в камне (мультфильм)  ...  \
# Белоснежка и семь гномов (мультфильм)                  0.170720  ...
# Ведьмина служба доставки                               0.146678  ...
# Верхом на помеле (мультфильм)                          0.097023  ...
# Дети против волшебников (мультфильм)                   0.136337  ...
# Добрыня Никитич и Змей Горыныч                         0.081335  ...
# Дракон и тапочка королевы                              0.311271  ...
# Карлик Нос (мультфильм)                                0.108028  ...
# Маленькая колдунья (мультфильм)                        0.115937  ...
# Мальчик из Неаполя                                     0.127251  ...
# Меч в камне (мультфильм)                               1.000000  ...
# Мэри и ведьмин цветок                                  0.041656  ...
# Ореховый прутик                                        0.094527  ...
# Паранорман, или Как приручить зомби                    0.090751  ...
# Рапунцель: Запутанная история                          0.210093  ...
# Русалочка (мультфильм, 1989)                           0.192390  ...
# Русалочка 2: Возвращение в море                        0.172221  ...
# Скуби-Ду и призрак ведьмы                              0.058402  ...
# Скуби-Ду и Школа вампиров                              0.064379  ...
# Скуби-Ду, где ты!                                      0.065733  ...
# Спящая красавица (мультфильм)                          0.193585  ...
# Три богатыря на дальних берегах                        0.070596  ...
# Унесённые призраками                                   0.160301  ...
# Храбрая сердцем                                        0.246253  ...
# Bewitched Bunny                                        0.107089  ...
# Brynhildr in the Darkness                              0.054373  ...
# Rosario + Vampire                                      0.093699  ...
#
#                                        Скуби-Ду и призрак ведьмы  \
# Белоснежка и семь гномов (мультфильм)                   0.063206
# Ведьмина служба доставки                                0.129954
# Верхом на помеле (мультфильм)                           0.164969
# Дети против волшебников (мультфильм)                    0.073403
# Добрыня Никитич и Змей Горыныч                          0.061117
# Дракон и тапочка королевы                               0.077147
# Карлик Нос (мультфильм)                                 0.082988
# Маленькая колдунья (мультфильм)                         0.162724
# Мальчик из Неаполя                                      0.049806
# Меч в камне (мультфильм)                                0.058402
# Мэри и ведьмин цветок                                   0.068692
# Ореховый прутик                                         0.047682
# Паранорман, или Как приручить зомби                     0.085831
# Рапунцель: Запутанная история                           0.101422
# Русалочка (мультфильм, 1989)                            0.067590
# Русалочка 2: Возвращение в море                         0.051992
# Скуби-Ду и призрак ведьмы                               1.000000
# Скуби-Ду и Школа вампиров                               0.420520
# Скуби-Ду, где ты!                                       0.646066
# Спящая красавица (мультфильм)                           0.066870
# Три богатыря на дальних берегах                         0.081703
# Унесённые призраками                                    0.162332
# Храбрая сердцем                                         0.108757
# Bewitched Bunny                                         0.179655
# Brynhildr in the Darkness                               0.060373
# Rosario + Vampire                                       0.071381
#
#                                        Скуби-Ду и Школа вампиров  \
# Белоснежка и семь гномов (мультфильм)                   0.041694
# Ведьмина служба доставки                                0.056315
# Верхом на помеле (мультфильм)                           0.079537
# Дети против волшебников (мультфильм)                    0.037811
# Добрыня Никитич и Змей Горыныч                          0.031406
# Дракон и тапочка королевы                               0.090757
# Карлик Нос (мультфильм)                                 0.035106
# Маленькая колдунья (мультфильм)                         0.027210
# Мальчик из Неаполя                                      0.020063
# Меч в камне (мультфильм)                                0.064379
# Мэри и ведьмин цветок                                   0.046644
# Ореховый прутик                                         0.038955
# Паранорман, или Как приручить зомби                     0.033555
# Рапунцель: Запутанная история                           0.061512
# Русалочка (мультфильм, 1989)                            0.048402
# Русалочка 2: Возвращение в море                         0.101915
# Скуби-Ду и призрак ведьмы                               0.420520
# Скуби-Ду и Школа вампиров                               1.000000
# Скуби-Ду, где ты!                                       0.548298
# Спящая красавица (мультфильм)                           0.028261
# Три богатыря на дальних берегах                         0.068980
# Унесённые призраками                                    0.111925
# Храбрая сердцем                                         0.140143
# Bewitched Bunny                                         0.098596
# Brynhildr in the Darkness                               0.047965
# Rosario + Vampire                                       0.082089
#
#                                        Скуби-Ду, где ты!  \
# Белоснежка и семь гномов (мультфильм)           0.086911
# Ведьмина служба доставки                        0.104275
# Верхом на помеле (мультфильм)                   0.071800
# Дети против волшебников (мультфильм)            0.101538
# Добрыня Никитич и Змей Горыныч                  0.061845
# Дракон и тапочка королевы                       0.023731
# Карлик Нос (мультфильм)                         0.086095
# Маленькая колдунья (мультфильм)                 0.075447
# Мальчик из Неаполя                              0.062069
# Меч в камне (мультфильм)                        0.065733
# Мэри и ведьмин цветок                           0.018807
# Ореховый прутик                                 0.057274
# Паранорман, или Как приручить зомби             0.036185
# Рапунцель: Запутанная история                   0.114781
# Русалочка (мультфильм, 1989)                    0.072603
# Русалочка 2: Возвращение в море                 0.047652
# Скуби-Ду и призрак ведьмы                       0.646066
# Скуби-Ду и Школа вампиров                       0.548298
# Скуби-Ду, где ты!                               1.000000
# Спящая красавица (мультфильм)                   0.087156
# Три богатыря на дальних берегах                 0.055619
# Унесённые призраками                            0.131422
# Храбрая сердцем                                 0.093158
# Bewitched Bunny                                 0.048196
# Brynhildr in the Darkness                       0.039109
# Rosario + Vampire                               0.120364
#
#                                        Спящая красавица (мультфильм)  \
# Белоснежка и семь гномов (мультфильм)                       0.439205
# Ведьмина служба доставки                                    0.316139
# Верхом на помеле (мультфильм)                               0.130721
# Дети против волшебников (мультфильм)                        0.241817
# Добрыня Никитич и Змей Горыныч                              0.129189
# Дракон и тапочка королевы                                   0.137870
# Карлик Нос (мультфильм)                                     0.225371
# Маленькая колдунья (мультфильм)                             0.182808
# Мальчик из Неаполя                                          0.144441
# Меч в камне (мультфильм)                                    0.193585
# Мэри и ведьмин цветок                                       0.100094
# Ореховый прутик                                             0.144042
# Паранорман, или Как приручить зомби                         0.080852
# Рапунцель: Запутанная история                               0.453597
# Русалочка (мультфильм, 1989)                                0.265835
# Русалочка 2: Возвращение в море                             0.203643
# Скуби-Ду и призрак ведьмы                                   0.066870
# Скуби-Ду и Школа вампиров                                   0.028261
# Скуби-Ду, где ты!                                           0.087156
# Спящая красавица (мультфильм)                               1.000000
# Три богатыря на дальних берегах                             0.134681
# Унесённые призраками                                        0.286394
# Храбрая сердцем                                             0.325187
# Bewitched Bunny                                             0.183751
# Brynhildr in the Darkness                                   0.117093
# Rosario + Vampire                                           0.174062
#
#                                        Три богатыря на дальних берегах  \
# Белоснежка и семь гномов (мультфильм)                         0.123528
# Ведьмина служба доставки                                      0.173044
# Верхом на помеле (мультфильм)                                 0.102420
# Дети против волшебников (мультфильм)                          0.236183
# Добрыня Никитич и Змей Горыныч                                0.221127
# Дракон и тапочка королевы                                     0.074963
# Карлик Нос (мультфильм)                                       0.134984
# Маленькая колдунья (мультфильм)                               0.151805
# Мальчик из Неаполя                                            0.104591
# Меч в камне (мультфильм)                                      0.070596
# Мэри и ведьмин цветок                                         0.052027
# Ореховый прутик                                               0.084538
# Паранорман, или Как приручить зомби                           0.061355
# Рапунцель: Запутанная история                                 0.207408
# Русалочка (мультфильм, 1989)                                  0.163307
# Русалочка 2: Возвращение в море                               0.098180
# Скуби-Ду и призрак ведьмы                                     0.081703
# Скуби-Ду и Школа вампиров                                     0.068980
# Скуби-Ду, где ты!                                             0.055619
# Спящая красавица (мультфильм)                                 0.134681
# Три богатыря на дальних берегах                               1.000000
# Унесённые призраками                                          0.182309
# Храбрая сердцем                                               0.162815
# Bewitched Bunny                                               0.124010
# Brynhildr in the Darkness                                     0.086178
# Rosario + Vampire                                             0.110872
#
#                                        Унесённые призраками  Храбрая сердцем  \
# Белоснежка и семь гномов (мультфильм)              0.261208         0.297624
# Ведьмина служба доставки                           0.609075         0.290407
# Верхом на помеле (мультфильм)                      0.287338         0.210435
# Дети против волшебников (мультфильм)               0.316917         0.252330
# Добрыня Никитич и Змей Горыныч                     0.169802         0.154587
# Дракон и тапочка королевы                          0.092582         0.258509
# Карлик Нос (мультфильм)                            0.281434         0.232394
# Маленькая колдунья (мультфильм)                    0.139749         0.239525
# Мальчик из Неаполя                                 0.124475         0.185838
# Меч в камне (мультфильм)                           0.160301         0.246253
# Мэри и ведьмин цветок                              0.092544         0.074195
# Ореховый прутик                                    0.148609         0.188637
# Паранорман, или Как приручить зомби                0.168962         0.104749
# Рапунцель: Запутанная история                      0.379366         0.454429
# Русалочка (мультфильм, 1989)                       0.218838         0.226410
# Русалочка 2: Возвращение в море                    0.171646         0.236637
# Скуби-Ду и призрак ведьмы                          0.162332         0.108757
# Скуби-Ду и Школа вампиров                          0.111925         0.140143
# Скуби-Ду, где ты!                                  0.131422         0.093158
# Спящая красавица (мультфильм)                      0.286394         0.325187
# Три богатыря на дальних берегах                    0.182309         0.162815
# Унесённые призраками                               1.000000         0.291545
# Храбрая сердцем                                    0.291545         1.000000
# Bewitched Bunny                                    0.074964         0.206625
# Brynhildr in the Darkness                          0.336248         0.132789
# Rosario + Vampire                                  0.319660         0.144424
#
#                                        Bewitched Bunny  \
# Белоснежка и семь гномов (мультфильм)         0.148002
# Ведьмина служба доставки                      0.091131
# Верхом на помеле (мультфильм)                 0.148059
# Дети против волшебников (мультфильм)          0.119066
# Добрыня Никитич и Змей Горыныч                0.072556
# Дракон и тапочка королевы                     0.175611
# Карлик Нос (мультфильм)                       0.107315
# Маленькая колдунья (мультфильм)               0.204417
# Мальчик из Неаполя                            0.159527
# Меч в камне (мультфильм)                      0.107089
# Мэри и ведьмин цветок                         0.056708
# Ореховый прутик                               0.147306
# Паранорман, или Как приручить зомби           0.067156
# Рапунцель: Запутанная история                 0.264381
# Русалочка (мультфильм, 1989)                  0.105901
# Русалочка 2: Возвращение в море               0.080369
# Скуби-Ду и призрак ведьмы                     0.179655
# Скуби-Ду и Школа вампиров                     0.098596
# Скуби-Ду, где ты!                             0.048196
# Спящая красавица (мультфильм)                 0.183751
# Три богатыря на дальних берегах               0.124010
# Унесённые призраками                          0.074964
# Храбрая сердцем                               0.206625
# Bewitched Bunny                               1.000000
# Brynhildr in the Darkness                     0.058549
# Rosario + Vampire                             0.068687
#
#                                        Brynhildr in the Darkness  \
# Белоснежка и семь гномов (мультфильм)                   0.102661
# Ведьмина служба доставки                                0.327424
# Верхом на помеле (мультфильм)                           0.063716
# Дети против волшебников (мультфильм)                    0.117681
# Добрыня Никитич и Змей Горыныч                          0.077857
# Дракон и тапочка королевы                               0.034761
# Карлик Нос (мультфильм)                                 0.084507
# Маленькая колдунья (мультфильм)                         0.067282
# Мальчик из Неаполя                                      0.036661
# Меч в камне (мультфильм)                                0.054373
# Мэри и ведьмин цветок                                   0.112283
# Ореховый прутик                                         0.062153
# Паранорман, или Как приручить зомби                     0.030615
# Рапунцель: Запутанная история                           0.163183
# Русалочка (мультфильм, 1989)                            0.093033
# Русалочка 2: Возвращение в море                         0.067543
# Скуби-Ду и призрак ведьмы                               0.060373
# Скуби-Ду и Школа вампиров                               0.047965
# Скуби-Ду, где ты!                                       0.039109
# Спящая красавица (мультфильм)                           0.117093
# Три богатыря на дальних берегах                         0.086178
# Унесённые призраками                                    0.336248
# Храбрая сердцем                                         0.132789
# Bewitched Bunny                                         0.058549
# Brynhildr in the Darkness                               1.000000
# Rosario + Vampire                                       0.280242
#
#                                        Rosario + Vampire
# Белоснежка и семь гномов (мультфильм)           0.158875
# Ведьмина служба доставки                        0.322007
# Верхом на помеле (мультфильм)                   0.088300
# Дети против волшебников (мультфильм)            0.173346
# Добрыня Никитич и Змей Горыныч                  0.121395
# Дракон и тапочка королевы                       0.047898
# Карлик Нос (мультфильм)                         0.160573
# Маленькая колдунья (мультфильм)                 0.069002
# Мальчик из Неаполя                              0.082000
# Меч в камне (мультфильм)                        0.093699
# Мэри и ведьмин цветок                           0.073408
# Ореховый прутик                                 0.089989
# Паранорман, или Как приручить зомби             0.036802
# Рапунцель: Запутанная история                   0.213947
# Русалочка (мультфильм, 1989)                    0.146422
# Русалочка 2: Возвращение в море                 0.110377
# Скуби-Ду и призрак ведьмы                       0.071381
# Скуби-Ду и Школа вампиров                       0.082089
# Скуби-Ду, где ты!                               0.120364
# Спящая красавица (мультфильм)                   0.174062
# Три богатыря на дальних берегах                 0.110872
# Унесённые призраками                            0.319660
# Храбрая сердцем                                 0.144424
# Bewitched Bunny                                 0.068687
# Brynhildr in the Darkness                       0.280242
# Rosario + Vampire                               1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# Посмотрим, какие тексты наиболее похожи на текст про мультфильм "Ведьмина служба доставки":

# %%
df["Ведьмина служба доставки"].sort_values(ascending=False)
# Out:
# Ведьмина служба доставки                 1.000000
# Унесённые призраками                     0.609075
# Рапунцель: Запутанная история            0.388703
# Дети против волшебников (мультфильм)     0.365360
# Brynhildr in the Darkness                0.327424
# Rosario + Vampire                        0.322007
# Верхом на помеле (мультфильм)            0.321257
# Спящая красавица (мультфильм)            0.316139
# Белоснежка и семь гномов (мультфильм)    0.292333
# Храбрая сердцем                          0.290407
# Карлик Нос (мультфильм)                  0.277731
# Русалочка (мультфильм, 1989)             0.245649
# Маленькая колдунья (мультфильм)          0.226747
# Три богатыря на дальних берегах          0.173044
# Русалочка 2: Возвращение в море          0.169138
# Добрыня Никитич и Змей Горыныч           0.162681
# Мэри и ведьмин цветок                    0.156344
# Мальчик из Неаполя                       0.156136
# Ореховый прутик                          0.147372
# Меч в камне (мультфильм)                 0.146678
# Скуби-Ду и призрак ведьмы                0.129954
# Скуби-Ду, где ты!                        0.104275
# Паранорман, или Как приручить зомби      0.095394
# Bewitched Bunny                          0.091131
# Дракон и тапочка королевы                0.065369
# Скуби-Ду и Школа вампиров                0.056315
# Name: Ведьмина служба доставки, dtype: float64

# %% [markdown]
# Попробуем визуализировать матрицу близости:

# %%
import seaborn as sns

# %%
sns.clustermap(df, figsize=(20, 10))
plt.title('Кластеризация текстов по близости')
plt.show()

# %% [markdown]
# Как мы можем заметить, в целом тексты кластеризируются адекватно (например, все статьи про Скуби-Ду оказались в одном кластере), две "Русалочки" также объединены.
